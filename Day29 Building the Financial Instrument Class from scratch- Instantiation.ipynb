# %%
import pytz

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import yfinance as yf
plt.style.use("seaborn-v0_8")

# %%
class FinancialInstrument():
    pass

# %%
stock = FinancialInstrument()

# %%
stock

# %%
class FinancialInstrument():
    def __init__(self, ticker, start, end):
        self.ticker = ticker
        self.start = start
        self.end = end

# %%
stock = FinancialInstrument("AAPL", "2015-01-01", "2019-12-31")

# %%
stock

# %%
stock.ticker
# Out:
# 'AAPL'

# %%
stock.start
# Out:
# '2015-01-01'

# %%
stock.end
# Out:
# '2019-12-31'

# %% [markdown]
# ### The method get_data()

# %%
yf.download("VEDL.NS", "2000-01-01", "2024-02-21").Close.to_frame()
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                  Close
# Date
# 2000-01-03    2.908750
# 2000-01-04    2.867500
# 2000-01-05    2.850000
# 2000-01-06    2.982500
# 2000-01-07    2.912500
# ...                ...
# 2024-02-14  279.649994
# 2024-02-15  267.950012
# 2024-02-16  266.799988
# 2024-02-19  270.149994
# 2024-02-20  270.149994
#
# [6028 rows x 1 columns]

# %%
raw = yf.download("VEDL.NS", "2000-01-01", "2024-02-23").Close.to_frame()
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
raw.rename(columns = {"Close": "price"}, inplace = True)

# %%
raw
# Out:
#                  price
# Date
# 2000-01-03    2.908750
# 2000-01-04    2.867500
# 2000-01-05    2.850000
# 2000-01-06    2.982500
# 2000-01-07    2.912500
# ...                ...
# 2024-02-16  266.799988
# 2024-02-19  270.149994
# 2024-02-20  270.149994
# 2024-02-21  270.000000
# 2024-02-22  271.500000
#
# [6030 rows x 1 columns]

# %%
import pytz

import yfinance as yf

from datetime import datetime as dt

tz = pytz.timezone("Asia/Kolkata")
start = tz.localize(dt(2001,1,1))
end = tz.localize(dt.today())

# %%
class FinancialInstrument():
    def __init__(self, ticker, start, end):
        self.ticker = ticker
        self.start = start
        self.end = end
        self.get_data()
        self.log_returns()
    def get_data(self):
#         tz = pytz.timezone("America/New_York")
#         start = tz.localize(dt(2001,1,1))
#         end = tz.localize(dt.today())
#         raw = yf.download("self.ticker", "self.start", "self.end", ignore_tz=False).Close.to_frame()
#         raw.rename(columns = {"Close": "price"}, inplace = True)
        self.data = raw
    def log_returns(self):
        self.data["log_returns"] = np.log(self.data.price/self.data.price.shift(1))

# %%
stock = FinancialInstrument("VEDL.NS", "2000-01-01", "2024-02-23")

# %%
stock.ticker
# Out:
# 'VEDL.NS'

# %%
stock.get_data()

# %%
stock.data
# Out:
#                  price  log_returns
# Date
# 2000-01-03    2.908750          NaN
# 2000-01-04    2.867500    -0.014283
# 2000-01-05    2.850000    -0.006122
# 2000-01-06    2.982500     0.045443
# 2000-01-07    2.912500    -0.023750
# ...                ...          ...
# 2024-02-16  266.799988    -0.004301
# 2024-02-19  270.149994     0.012478
# 2024-02-20  270.149994     0.000000
# 2024-02-21  270.000000    -0.000555
# 2024-02-22  271.500000     0.005540
#
# [6030 rows x 2 columns]

# %% [markdown]
# ### The method log_returns()

# %%
stock.log_returns()

# %%
stock.data
# Out:
#                  price  log_returns
# Date
# 2000-01-03    2.908750          NaN
# 2000-01-04    2.867500    -0.014283
# 2000-01-05    2.850000    -0.006122
# 2000-01-06    2.982500     0.045443
# 2000-01-07    2.912500    -0.023750
# ...                ...          ...
# 2024-02-16  266.799988    -0.004301
# 2024-02-19  270.149994     0.012478
# 2024-02-20  270.149994     0.000000
# 2024-02-21  270.000000    -0.000555
# 2024-02-22  271.500000     0.005540
#
# [6030 rows x 2 columns]

# %% [markdown]
# ## (String) Representation

# %%
stock

# %%
print(stock)
# Out:
# <__main__.FinancialInstrument object at 0x0000022637E7AED0>

# %%
class FinancialInstrument():
    def __init__(self, ticker, start, end):
        self.ticker = ticker
        self.start = start
        self.end = end
        self.get_data()
        self.log_returns()
     
    def __repr__(self):
        return "FinancialInstrument(ticker = {}, start = {}, end = {})".format(self.ticker, self.start, self.end)
        
    def get_data(self):
        self.data = raw
        
    def log_returns(self):
        self.data["log_returns"] = np.log(self.data.price/self.data.price.shift(1))

# %%
stock = FinancialInstrument("VEDL.NS", "2000-01-01", "2024-02-23")

# %%
stock
# Out:
# FinancialInstrument(ticker = VEDL.NS, start = 2000-01-01, end = 2024-02-23)

# %%
print(stock)
# Out:
# FinancialInstrument(ticker = VEDL.NS, start = 2000-01-01, end = 2024-02-23)

# %% [markdown]
# ### The methods plot_data() and plot_returns()

# %%
stock
# Out:
# FinancialInstrument(ticker = VEDL.NS, start = 2000-01-01, end = 2024-02-23)

# %%
stock.data
# Out:
#                  price  log_returns
# Date
# 2000-01-03    2.908750          NaN
# 2000-01-04    2.867500    -0.014283
# 2000-01-05    2.850000    -0.006122
# 2000-01-06    2.982500     0.045443
# 2000-01-07    2.912500    -0.023750
# ...                ...          ...
# 2024-02-16  266.799988    -0.004301
# 2024-02-19  270.149994     0.012478
# 2024-02-20  270.149994     0.000000
# 2024-02-21  270.000000    -0.000555
# 2024-02-22  271.500000     0.005540
#
# [6030 rows x 2 columns]

# %%
class FinancialInstrument():
    def __init__(self, ticker, start, end):
        self.ticker = ticker
        self.start = start
        self.end = end
        self.get_data()
        self.log_returns()
     
    def __repr__(self):
        return "FinancialInstrument(ticker = {}, start = {}, end = {})".format(self.ticker, self.start, self.end)
        
    def get_data(self):
        self.data = raw
        
    def log_returns(self):
        self.data["log_returns"] = np.log(self.data.price/self.data.price.shift(1))
        
    def plot_prices(self):
        self.data.price.plot(figsize = (12, 8))
        plt.title("Price Chart: {}".format(self.ticker), fontsize = 15)
        
    def plot_returns(self, kind = "ts"):
        if kind == "ts":
            self.data.log_returns.plot(figsize =(12,8))
            plt.title("Returns: {}".format(self.ticker), fontsize =15)
        elif kind =="hist":
            self.data.log_returns.hist(figsize = (12,8), bins = int(np.sqrt(len(self.data))))
            plt.title("Frequency of Returns: {}".format(self.ticker), fontsize = 15)

# %%
stock = FinancialInstrument("VEDL.NS", "2000-01-01", "2024-02-23")

# %%
stock.plot_prices()

# %%
stock.plot_returns()

# %%
stock.plot_returns(kind = "hist")

# %% [markdown]
# ## Encapsulation

# %%
raw = yf.download("ASHOKLEY.NS", "2000-01-01", "2024-02-21").Close.to_frame()
raw.rename(columns = {"Close": "price"}, inplace = True)
raw
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                  price
# Date
# 2002-07-01    5.970000
# 2002-07-02    5.850000
# 2002-07-03    5.860000
# 2002-07-04    5.895000
# 2002-07-05    5.860000
# ...                ...
# 2024-02-14  173.649994
# 2024-02-15  174.500000
# 2024-02-16  174.199997
# 2024-02-19  172.199997
# 2024-02-20  172.949997
#
# [5377 rows x 1 columns]

# %%
class FinancialInstrument():
    def __init__(self, ticker, start, end):
        self.ticker = ticker
        self.start = start
        self.end = end
        self.get_data()
        self.log_returns()
     
    def __repr__(self):
        return "FinancialInstrument(ticker = {}, start = {}, end = {})".format(self.ticker, self.start, self.end)
        
    def get_data(self):
        self.data = raw
        
    def log_returns(self):
        self.data["log_returns"] = np.log(self.data.price/self.data.price.shift(1))
        
    def plot_prices(self):
        self.data.price.plot(figsize = (12, 8))
        plt.title("Price Chart: {}".format(self.ticker), fontsize = 15)
        
    def plot_returns(self, kind = "ts"):
        if kind == "ts":
            self.data.log_returns.plot(figsize =(12,8))
            plt.title("Returns: {}".format(self.ticker), fontsize =15)
        elif kind =="hist":
            self.data.log_returns.hist(figsize = (12,8), bins = int(np.sqrt(len(self.data))))
            plt.title("Frequency of Returns: {}".format(self.ticker), fontsize = 15)

# %%
stock = FinancialInstrument("ASHOKLEY.NS", "2000-01-01", "2024-02-23")

# %%
stock.ticker
# Out:
# 'ASHOKLEY.NS'

# %%
stock.plot_prices()

# %%
class FinancialInstrument():
    def __init__(self, ticker, start, end):
        self._ticker = ticker
        self.start = start
        self.end = end
        self.get_data()
        self.log_returns()
     
    def __repr__(self):
        return "FinancialInstrument(ticker = {}, start = {}, end = {})".format(self._ticker, self.start, self.end)
        
    def get_data(self):
        self.data = raw
        
    def log_returns(self):
        self.data["log_returns"] = np.log(self.data.price/self.data.price.shift(1))
        
    def plot_prices(self):
        self.data.price.plot(figsize = (12, 8))
        plt.title("Price Chart: {}".format(self._ticker), fontsize = 15)
        
    def plot_returns(self, kind = "ts"):
        if kind == "ts":
            self.data.log_returns.plot(figsize =(12,8))
            plt.title("Returns: {}".format(self._ticker), fontsize =15)
        elif kind =="hist":
            self.data.log_returns.hist(figsize = (12,8), bins = int(np.sqrt(len(self.data))))
            plt.title("Frequency of Returns: {}".format(self._ticker), fontsize = 15)

# %%
stock = FinancialInstrument("ASHOKLEY.NS", "2000-01-01", "2024-02-23")

# %%
stock
# Out:
# FinancialInstrument(ticker = ASHOKLEY.NS, start = 2000-01-01, end = 2024-02-23)

# %%
stock.ticker
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[113], line 1
# ----> 1 stock.ticker
#
# AttributeError: 'FinancialInstrument' object has no attribute 'ticker'

# %%
stock._ticker
# Out:
# 'ASHOKLEY.NS'

# %% [markdown]
# ### The Method set_ticker()

# %%
class FinancialInstrument():
    def __init__(self, ticker, start, end):
        self._ticker = ticker
        self.start = start
        self.end = end
        self.get_data()
        self.log_returns()
     
    def __repr__(self):
        return "FinancialInstrument(ticker = {}, start = {}, end = {})".format(self._ticker, self.start, self.end)
        
    def get_data(self):
        self.data = raw
        
    def log_returns(self):
        self.data["log_returns"] = np.log(self.data.price/self.data.price.shift(1))
        
    def plot_prices(self):
        self.data.price.plot(figsize = (12, 8))
        plt.title("Price Chart: {}".format(self._ticker), fontsize = 15)
        
    def plot_returns(self, kind = "ts"):
        if kind == "ts":
            self.data.log_returns.plot(figsize =(12,8))
            plt.title("Returns: {}".format(self._ticker), fontsize =15)
        elif kind =="hist":
            self.data.log_returns.hist(figsize = (12,8), bins = int(np.sqrt(len(self.data))))
            plt.title("Frequency of Returns: {}".format(self._ticker), fontsize = 15)
            
    def set_ticker(self, ticker =  None):
        if ticker is not None:
            self.ticker = ticker
            self.get_data()
            self.log_returns()

# %%
stock = FinancialInstrument("ASHOKLEY.NS", "2001-01-01", "2024-02-23")

# %%
stock.plot_prices()

# %%
stock.set_ticker("GE")

# %%
stock.plot_prices()

# %% [markdown]
# ### Adding more methods and performance metrics

# %%
class FinancialInstrument():
    def __init__(self, ticker, start, end):
        self._ticker = ticker
        self.start = start
        self.end = end
        self.get_data()
        self.log_returns()
     
    def __repr__(self):
        return "FinancialInstrument(ticker = {}, start = {}, end = {})".format(self._ticker, self.start, self.end)
        
    def get_data(self):
        self.data = raw
        
    def log_returns(self):
        self.data["log_returns"] = np.log(self.data.price/self.data.price.shift(1))
        
    def plot_prices(self):
        self.data.price.plot(figsize = (12, 8))
        plt.title("Price Chart: {}".format(self._ticker), fontsize = 15)
        
    def plot_returns(self, kind = "ts"):
        if kind == "ts":
            self.data.log_returns.plot(figsize =(12,8))
            plt.title("Returns: {}".format(self._ticker), fontsize =15)
        elif kind =="hist":
            self.data.log_returns.hist(figsize = (12,8), bins = int(np.sqrt(len(self.data))))
            plt.title("Frequency of Returns: {}".format(self._ticker), fontsize = 15)
            
    def set_ticker(self, ticker =  None):
        if ticker is not None:
            self.ticker = ticker
            self.get_data()
            self.log_returns()
            
    def mean_return (self, freq = None):
        if freq is None:
            return self.data.log_returns.mean()
        else:
            resampled_price = self.data.price.resample(freq).last()
            resampled_returns = np.log(resampled_price / resampled_price.shift(1))
            return resampled_returns.mean()
    
    def std_returns(self, freq = None):
        if freq is None:
            return self.data.log_returns.std()
        else:
            resampled_price = self.data.price.resample(freq).last()
            resampled_returns = np.log(resampled_price / resampled_price.shift(1))
            return resampled_returns.std()
        
    def annualized_perf(self):
        mean_return = round(self.data.log_returns.mean()*252, 3)
        risk = round(self.data.log_returns.std()*np.sqrt(252), 3)
        print("Return: {} | Risk: {}".format(mean_return, risk))

# %%
stock = FinancialInstrument("ASHOKLEY.NS", "2001-01-01", "2024-02-23")

# %%
stock.mean_return()
# Out:
# 0.0006261636208104778

# %%
stock.mean_return("m")
# Out:
# 0.0141100238892749

# %%
stock.std_returns()
# Out:
# 0.02642062788329043

# %%
stock.std_returns("m")
# Out:
# 0.1251677041214277

# %%
stock.annualized_perf()
# Out:
# Return: 0.158 | Risk: 0.419

# %% [markdown]
# ## Inheritance

# %%
class FinancialInstrument():
    def __init__(self, ticker, start, end):
        self._ticker = ticker
        self.start = start
        self.end = end
        self.get_data()
        self.log_returns()
     
    def __repr__(self):
        return "FinancialInstrument(ticker = {}, start = {}, end = {})".format(self._ticker, self.start, self.end)
        
    def get_data(self):
        #raw = yf.download("self.ticker", "self.start", "self.end", ignore_tz=False).Close.to_frame()
        #raw.rename(columns = {"Close": "price"}, inplace = True)
        self.data = raw
        
    def log_returns(self):
        self.data["log_returns"] = np.log(self.data.price/self.data.price.shift(1))
        
    def plot_prices(self):
        self.data.price.plot(figsize = (12, 8))
        plt.title("Price Chart: {}".format(self._ticker), fontsize = 15)
        
    def plot_returns(self, kind = "ts"):
        if kind == "ts":
            self.data.log_returns.plot(figsize =(12,8))
            plt.title("Returns: {}".format(self._ticker), fontsize =15)
        elif kind =="hist":
            self.data.log_returns.hist(figsize = (12,8), bins = int(np.sqrt(len(self.data))))
            plt.title("Frequency of Returns: {}".format(self._ticker), fontsize = 15)
            
    def set_ticker(self, ticker =  None):
        if ticker is not None:
            self.ticker = ticker
            self.get_data()
            self.log_returns()
            
    def mean_return (self, freq = None):
        if freq is None:
            return self.data.log_returns.mean()
        else:
            resampled_price = self.data.price.resample(freq).last()
            resampled_returns = np.log(resampled_price / resampled_price.shift(1))
            return resampled_returns.mean()
    
    def std_returns(self, freq = None):
        if freq is None:
            return self.data.log_returns.std()
        else:
            resampled_price = self.data.price.resample(freq).last()
            resampled_returns = np.log(resampled_price / resampled_price.shift(1))
            return resampled_returns.std()
        
    def annualized_perf(self):
        mean_return = round(self.data.log_returns.mean()*252, 3)
        risk = round(self.data.log_returns.std()*np.sqrt(252), 3)
        print("Return: {} | Risk: {}".format(mean_return, risk))

# %%
stock = FinancialInstrument("TCS.NS", "2001-01-01", "2024-02-23")

# %%
raw = yf.download("TCS.NS", "2000-01-01", "2024-02-21").Close.to_frame()
raw.rename(columns = {"Close": "price"}, inplace = True)
raw
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                   price
# Date
# 2002-08-12    39.700001
# 2002-08-13    39.162498
# 2002-08-14    36.462502
# 2002-08-15    36.462502
# 2002-08-16    36.375000
# ...                 ...
# 2024-02-14  4100.100098
# 2024-02-15  4103.200195
# 2024-02-16  4128.299805
# 2024-02-19  4103.799805
# 2024-02-20  4030.649902
#
# [5346 rows x 1 columns]

# %%
 stock.annualized_perf()
# Out:
# Return: 0.218 | Risk: 0.442

# %% [markdown]
# # Inheritance

# %% [markdown]
# ## Inheritance and the super() function

# %% [markdown]
# ## Docstrings
