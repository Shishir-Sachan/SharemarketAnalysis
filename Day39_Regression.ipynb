# %% [markdown]
# # Trading Strategies powered by Machine Learning - Regression

# %% [markdown]
# ## Linear Regression with scikit-learn - a simple Introduction

# %% [markdown]
# ![Screenshot%202024-03-08%20111327.png](attachment:Screenshot%202024-03-08%20111327.png)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use("seaborn-v0_8")

# %%
budget = np.array([5, 10, 17, 27, 35, 40, 42, 49, 54, 60])

# %%
revenue = np.array([2.6, 19. , 23.8, 26.9, 41.1, 58.3, 40.3, 58.7, 73.1, 69.7])

# %%
df = pd.DataFrame(data = {"revenue":revenue, "budget":budget})
df
# Out:
#    revenue  budget
# 0      2.6       5
# 1     19.0      10
# 2     23.8      17
# 3     26.9      27
# 4     41.1      35
# 5     58.3      40
# 6     40.3      42
# 7     58.7      49
# 8     73.1      54
# 9     69.7      60

# %%
plt.figure( figsize = (12, 8))
plt.scatter(x = df.budget, y = df.revenue, s = 50)
plt.xlabel("Budget", fontsize = 13)
plt.ylabel("Revenue", fontsize = 13)
plt.show()

# %% [markdown]
# __Linear Relationship between Budget and Revenue__:

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
from sklearn.linear_model import LinearRegression

# %%
lm = LinearRegression(fit_intercept = True)

# %%
lm.fit(X = df.budget.to_frame(), y = df.revenue) # fitting the model (Regression Line)
# Out:
# LinearRegression()

# %%
slope = lm.coef_ # slope of Regression Line
slope
# Out:
# array([1.19897684])

# %%
intercept = lm.intercept_ # intercept of Regression Line
intercept
# Out:
# 0.7046849757673783

# %%
df["pred"] = lm.predict(df.budget.to_frame())
df
# Out:
#    revenue  budget       pred
# 0      2.6       5   6.699569
# 1     19.0      10  12.694453
# 2     23.8      17  21.087291
# 3     26.9      27  33.077060
# 4     41.1      35  42.668875
# 5     58.3      40  48.663759
# 6     40.3      42  51.061712
# 7     58.7      49  59.454550
# 8     73.1      54  65.449435
# 9     69.7      60  72.643296

# %%
x_lin = np.array([0, 100])
y_lin = intercept + slope * x_lin

# %%
y_lin
# Out:
# array([  0.70468498, 120.60236941])

# %%
plt.figure( figsize = (12, 8))
plt.scatter(x = df.budget, y = df.revenue, s = 50, label = "Data")
plt.plot(x_lin, y_lin, c = "red", label = "Regression Line")
plt.xlabel("Budget", fontsize = 13)
plt.ylabel("Revenue", fontsize = 13)
plt.legend(fontsize = 13)
plt.show()

# %% [markdown]
# ## Making Predictions with Linear Regression

# %% [markdown]
# __new movies (observations/data points)__

# %%
budget_new = np.array([63, 66, 74, 80, 85])

# %%
revenue_new = np.array([74.2,  80.7, 98.2,  94.8, 101.7])

# %%
df_new = pd.DataFrame(data = {"revenue":revenue_new, "budget":budget_new})
df_new
# Out:
#    revenue  budget
# 0     74.2      63
# 1     80.7      66
# 2     98.2      74
# 3     94.8      80
# 4    101.7      85

# %%
df_new["pred"] = lm.predict(df_new.budget.to_frame())
df_new
# Out:
#    revenue  budget        pred
# 0     74.2      63   76.240226
# 1     80.7      66   79.837157
# 2     98.2      74   89.428971
# 3     94.8      80   96.622833
# 4    101.7      85  102.617717

# %%
plt.figure( figsize = (12, 8))
plt.scatter(x = df.budget, y = df.revenue, s = 50, label = "Data")
plt.plot(x_lin, y_lin, c = "red", label = "Regression Line")
plt.scatter(x = df_new.budget, y = df_new.revenue, s = 50, label = "New Data")
plt.xlabel("Budget", fontsize = 13)
plt.ylabel("Revenue", fontsize = 13)
plt.legend(fontsize = 13)
plt.show()

# %% [markdown]
# ## Overfitting

# %% [markdown]
# __Overfitting__: Model performs well on the original (training) dataset, but it does not generalize well to new data (test set).
# Overfitting happens when the __model is too complex__ (too many parameters) and detects subtle patterns (noise) in the training set.

# %% [markdown]
# Example: __Polynomial Model__ with degree = 9 (perfect fit)

# %% [markdown]
# ![image-3.png](attachment:image-3.png)

# %%
poly_m = np.polyfit(x = df.budget, y = df.revenue, deg = 9) # polynomial regression (deg = 9)

# %%
poly_m # 10 regression parameters (intercept + 9 regression coefficients)
# Out:
# array([ 2.31988762e-09, -6.91663857e-07,  8.80409588e-05, -6.24271102e-03,
#         2.69731803e-01, -7.29512946e+00,  1.21996447e+02, -1.19724559e+03,
#         6.13254339e+03, -1.21710591e+04])

# %%
x_poly = np.linspace(0, 100, 1000) # x values for polynomial regression line/curve

# %%
y_poly = np.polyval(poly_m, x_poly) # y values for polynomial regression line/curve

# %%
plt.figure( figsize = (12, 8))
plt.scatter(x = df.budget, y = df.revenue, s = 50, label = "Data")
plt.plot(x_lin, y_lin, c = "red", label = "Linear Regression Line")
plt.plot(x_poly, y_poly, label = "Polynomial Regression | deg = 9 (Overfit)",linestyle = "--", color = "red")
plt.scatter(x = df_new.budget, y = df_new.revenue, s = 50, label = "New Data")
plt.xlabel("Budget", fontsize = 13)
plt.ylabel("Revenue", fontsize = 13)
plt.legend(fontsize = 11, loc = 4)
plt.ylim(0, 150)
plt.show()

# %% [markdown]
# __Solutions__ to overcome overfitting:

# %% [markdown]
# - use a __simpler model__ with fewer parameters (linear rather than polynomial)<br>
# - more and better data (remove outliers & errors) <br>
# - constrain the model -> make the model more simple with __Regularization__

# %% [markdown]
# ##  Underfitting

# %% [markdown]
# __Underfitting__: Model performs neither well on the original (training) dataset, nor does it generalize well to new data (test set).
# Underfitting happens when the __model is too simple__ to learn the underlying structure of the data.

# %% [markdown]
# most simple (linear) model with only one paramter: __y = a__ <br>
# intercept == a (e.g. the mean)<br>
# slope == 0

# %%
mean = df.revenue.mean()
mean
# Out:
# 41.35000000000001

# %%
plt.figure( figsize = (12, 8))
plt.scatter(x = df.budget, y = df.revenue, s = 50, label = "Data")
plt.plot(x_lin, y_lin, c = "red", label = "Linear Regression Line")
plt.plot(x_poly, y_poly, label = "Polynomial Regression | deg = 9 (Overfit)",linestyle = "--", color = "red")
plt.hlines(y = mean, xmin = 0, xmax = 100, linestyle = "-.", color = "darkred", label = "Underfit")
plt.scatter(x = df_new.budget, y = df_new.revenue, s = 50, label = "New Data")
plt.xlabel("Budget", fontsize = 13)
plt.ylabel("Revenue", fontsize = 13)
plt.legend(fontsize = 11, loc = 4)
plt.ylim(0, 150)
plt.show()

# %% [markdown]
# __Solutions__ to overcome underfitting:

# %% [markdown]
# - use a __more powerful model__ with more parameters<br>
# - add more/better features (independent variables) to the algorithm -> Feature Engineering <br>
# - reduce the constraints of the model -> make it more complex with __less Regularization__

# %% [markdown]
# ## Getting the Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use("seaborn-v0_8")

# %%
data = pd.read_csv("five_minute.csv", parse_dates = ["time"], index_col = "time")

# %%
data
# Out:
#                               price
# time
# 2019-01-01 22:00:00+00:00  1.146580
# 2019-01-01 22:05:00+00:00  1.146350
# 2019-01-01 22:10:00+00:00  1.146320
# 2019-01-01 22:15:00+00:00  1.146320
# 2019-01-01 22:20:00+00:00  1.146530
# ...                             ...
# 2019-12-30 23:35:00+00:00  1.120180
# 2019-12-30 23:40:00+00:00  1.120210
# 2019-12-30 23:45:00+00:00  1.120295
# 2019-12-30 23:50:00+00:00  1.120275
# 2019-12-30 23:55:00+00:00  1.120130
#
# [73720 rows x 1 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 73720 entries, 2019-01-01 22:00:00+00:00 to 2019-12-30 23:55:00+00:00
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   price   73720 non-null  float64
# dtypes: float64(1)
# memory usage: 1.1 MB

# %%
data.plot(figsize = (12, 8))
plt.show()

# %%
data.loc["2019-06"].plot(figsize = (12, 8))
plt.show()

# %%
data["returns"] = np.log(data.div(data.shift(1)))

# %%
data
# Out:
#                               price   returns
# time
# 2019-01-01 22:00:00+00:00  1.146580       NaN
# 2019-01-01 22:05:00+00:00  1.146350 -0.000201
# 2019-01-01 22:10:00+00:00  1.146320 -0.000026
# 2019-01-01 22:15:00+00:00  1.146320  0.000000
# 2019-01-01 22:20:00+00:00  1.146530  0.000183
# ...                             ...       ...
# 2019-12-30 23:35:00+00:00  1.120180 -0.000004
# 2019-12-30 23:40:00+00:00  1.120210  0.000027
# 2019-12-30 23:45:00+00:00  1.120295  0.000076
# 2019-12-30 23:50:00+00:00  1.120275 -0.000018
# 2019-12-30 23:55:00+00:00  1.120130 -0.000129
#
# [73720 rows x 2 columns]

# %% [markdown]
# ## A simple Linear Model to predict Financial Returns (Part 1)

# %% [markdown]
# Correct: Predicting __Returns__ <br>
# Wrong: Predicting __Prices__

# %%
data
# Out:
#                               price   returns
# time
# 2019-01-01 22:00:00+00:00  1.146580       NaN
# 2019-01-01 22:05:00+00:00  1.146350 -0.000201
# 2019-01-01 22:10:00+00:00  1.146320 -0.000026
# 2019-01-01 22:15:00+00:00  1.146320  0.000000
# 2019-01-01 22:20:00+00:00  1.146530  0.000183
# ...                             ...       ...
# 2019-12-30 23:35:00+00:00  1.120180 -0.000004
# 2019-12-30 23:40:00+00:00  1.120210  0.000027
# 2019-12-30 23:45:00+00:00  1.120295  0.000076
# 2019-12-30 23:50:00+00:00  1.120275 -0.000018
# 2019-12-30 23:55:00+00:00  1.120130 -0.000129
#
# [73720 rows x 2 columns]

# %%
data["lag1"] = data.returns.shift(1)

# %%
data.dropna(inplace = True)

# %%
data
# Out:
#                               price   returns      lag1
# time
# 2019-01-01 22:10:00+00:00  1.146320 -0.000026 -0.000201
# 2019-01-01 22:15:00+00:00  1.146320  0.000000 -0.000026
# 2019-01-01 22:20:00+00:00  1.146530  0.000183  0.000000
# 2019-01-01 22:25:00+00:00  1.146475 -0.000048  0.000183
# 2019-01-01 22:30:00+00:00  1.146455 -0.000017 -0.000048
# ...                             ...       ...       ...
# 2019-12-30 23:35:00+00:00  1.120180 -0.000004 -0.000112
# 2019-12-30 23:40:00+00:00  1.120210  0.000027 -0.000004
# 2019-12-30 23:45:00+00:00  1.120295  0.000076  0.000027
# 2019-12-30 23:50:00+00:00  1.120275 -0.000018  0.000076
# 2019-12-30 23:55:00+00:00  1.120130 -0.000129 -0.000018
#
# [73718 rows x 3 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 73718 entries, 2019-01-01 22:10:00+00:00 to 2019-12-30 23:55:00+00:00
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   price    73718 non-null  float64
#  1   returns  73718 non-null  float64
#  2   lag1     73718 non-null  float64
# dtypes: float64(3)
# memory usage: 2.2 MB

# %%
data.iloc[:, -2:].plot(kind = "scatter", x = "lag1", y = "returns")
plt.xlim(-0.005, 0.005)
plt.ylim(-0.005, 0.005)
plt.show()

# %% [markdown]
# ## A simple Linear Model to predict Financial Returns (Part 2)

# %%
from sklearn.linear_model import LinearRegression

# %%
lm = LinearRegression(fit_intercept = True)

# %%
lm.fit(data.lag1.to_frame(), data.returns)
# Out:
# LinearRegression()

# %%
slope = lm.coef_
slope
# Out:
# array([-0.03350837])

# %%
intercept = lm.intercept_
intercept
# Out:
# -3.2442471445009334e-07

# %%
data["pred"] = lm.predict(data.lag1.to_frame())

# %%
data
# Out:
#                               price   returns      lag1          pred
# time
# 2019-01-01 22:10:00+00:00  1.146320 -0.000026 -0.000201  6.397912e-06
# 2019-01-01 22:15:00+00:00  1.146320  0.000000 -0.000026  5.525013e-07
# 2019-01-01 22:20:00+00:00  1.146530  0.000183  0.000000 -3.244247e-07
# 2019-01-01 22:25:00+00:00  1.146475 -0.000048  0.000183 -6.462425e-06
# 2019-01-01 22:30:00+00:00  1.146455 -0.000017 -0.000048  1.283038e-06
# ...                             ...       ...       ...           ...
# 2019-12-30 23:35:00+00:00  1.120180 -0.000004 -0.000112  3.414522e-06
# 2019-12-30 23:40:00+00:00  1.120210  0.000027 -0.000004 -1.748582e-07
# 2019-12-30 23:45:00+00:00  1.120295  0.000076  0.000027 -1.221814e-06
# 2019-12-30 23:50:00+00:00  1.120275 -0.000018  0.000076 -2.866897e-06
# 2019-12-30 23:55:00+00:00  1.120130 -0.000129 -0.000018  2.737867e-07
#
# [73718 rows x 4 columns]

# %%
plt.figure(figsize = (12, 8))
plt.scatter(x = data.lag1, y = data.returns, label = "Data")
plt.plot(data.lag1, data.pred, c = "red", label = "Linear Regression")
plt.xlim(-0.005, 0.005)
plt.ylim(-0.005, 0.005)
plt.legend(fontsize = 13)
plt.xlabel("Lag1 Returns", fontsize = 13)
plt.ylabel("Returns", fontsize = 13)
plt.show()

# %%
data
# Out:
#                               price   returns      lag1          pred
# time
# 2019-01-01 22:10:00+00:00  1.146320 -0.000026 -0.000201  6.397912e-06
# 2019-01-01 22:15:00+00:00  1.146320  0.000000 -0.000026  5.525013e-07
# 2019-01-01 22:20:00+00:00  1.146530  0.000183  0.000000 -3.244247e-07
# 2019-01-01 22:25:00+00:00  1.146475 -0.000048  0.000183 -6.462425e-06
# 2019-01-01 22:30:00+00:00  1.146455 -0.000017 -0.000048  1.283038e-06
# ...                             ...       ...       ...           ...
# 2019-12-30 23:35:00+00:00  1.120180 -0.000004 -0.000112  3.414522e-06
# 2019-12-30 23:40:00+00:00  1.120210  0.000027 -0.000004 -1.748582e-07
# 2019-12-30 23:45:00+00:00  1.120295  0.000076  0.000027 -1.221814e-06
# 2019-12-30 23:50:00+00:00  1.120275 -0.000018  0.000076 -2.866897e-06
# 2019-12-30 23:55:00+00:00  1.120130 -0.000129 -0.000018  2.737867e-07
#
# [73718 rows x 4 columns]

# %%
data[["returns", "pred"]].plot(figsize = (12, 8))
plt.show() # model fails to predict the magnitude of returns

# %%
data.pred = np.sign(data.pred) # maybe the model can predict the market direction (-1 / +1)

# %%
data
# Out:
#                               price   returns      lag1  pred
# time
# 2019-01-01 22:10:00+00:00  1.146320 -0.000026 -0.000201   1.0
# 2019-01-01 22:15:00+00:00  1.146320  0.000000 -0.000026   1.0
# 2019-01-01 22:20:00+00:00  1.146530  0.000183  0.000000  -1.0
# 2019-01-01 22:25:00+00:00  1.146475 -0.000048  0.000183  -1.0
# 2019-01-01 22:30:00+00:00  1.146455 -0.000017 -0.000048   1.0
# ...                             ...       ...       ...   ...
# 2019-12-30 23:35:00+00:00  1.120180 -0.000004 -0.000112   1.0
# 2019-12-30 23:40:00+00:00  1.120210  0.000027 -0.000004  -1.0
# 2019-12-30 23:45:00+00:00  1.120295  0.000076  0.000027  -1.0
# 2019-12-30 23:50:00+00:00  1.120275 -0.000018  0.000076  -1.0
# 2019-12-30 23:55:00+00:00  1.120130 -0.000129 -0.000018   1.0
#
# [73718 rows x 4 columns]

# %%
np.sign(data.returns * data.pred)
# Out:
# time
# 2019-01-01 22:10:00+00:00   -1.0
# 2019-01-01 22:15:00+00:00    0.0
# 2019-01-01 22:20:00+00:00   -1.0
# 2019-01-01 22:25:00+00:00    1.0
# 2019-01-01 22:30:00+00:00   -1.0
#                             ...
# 2019-12-30 23:35:00+00:00   -1.0
# 2019-12-30 23:40:00+00:00   -1.0
# 2019-12-30 23:45:00+00:00   -1.0
# 2019-12-30 23:50:00+00:00    1.0
# 2019-12-30 23:55:00+00:00   -1.0
# Length: 73718, dtype: float64

# %%
hits = np.sign(data.returns * data.pred).value_counts()

# %%
hits
# Out:
#  1.0    37451
# -1.0    34308
#  0.0     1959
# Name: count, dtype: int64

# %%
hit_ratio = hits[1.0] / sum(hits)
hit_ratio # percentage of correctly forecasted market directions
# Out:
# 0.5080306031091457

# %% [markdown]
# ## A Multiple Regression Model to predict Financial Returns

# %% [markdown]
# __Adding more Features - a multiple Regression Model__

# %%
data = pd.read_csv("five_minute.csv", parse_dates = ["time"], index_col = "time")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 73720 entries, 2019-01-01 22:00:00+00:00 to 2019-12-30 23:55:00+00:00
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   price   73720 non-null  float64
# dtypes: float64(1)
# memory usage: 1.1 MB

# %%
data.dropna(inplace = True)

# %%
data["returns"] = np.log(data.div(data.shift(1)))

# %%
lags = 5

# %%
cols = []
for lag in range(1, lags + 1):
    col = "lag{}".format(lag)
    data[col] = data.returns.shift(lag)
    cols.append(col)
data.dropna(inplace = True)

# %%
data
# Out:
#                               price   returns      lag1      lag2      lag3  \
# time
# 2019-01-01 22:30:00+00:00  1.146455 -0.000017 -0.000048  0.000183  0.000000
# 2019-01-01 22:35:00+00:00  1.146455  0.000000 -0.000017 -0.000048  0.000183
# 2019-01-01 22:40:00+00:00  1.146370 -0.000074  0.000000 -0.000017 -0.000048
# 2019-01-01 22:45:00+00:00  1.146315 -0.000048 -0.000074  0.000000 -0.000017
# 2019-01-01 22:50:00+00:00  1.146475  0.000140 -0.000048 -0.000074  0.000000
# ...                             ...       ...       ...       ...       ...
# 2019-12-30 23:35:00+00:00  1.120180 -0.000004 -0.000112 -0.000018  0.000022
# 2019-12-30 23:40:00+00:00  1.120210  0.000027 -0.000004 -0.000112 -0.000018
# 2019-12-30 23:45:00+00:00  1.120295  0.000076  0.000027 -0.000004 -0.000112
# 2019-12-30 23:50:00+00:00  1.120275 -0.000018  0.000076  0.000027 -0.000004
# 2019-12-30 23:55:00+00:00  1.120130 -0.000129 -0.000018  0.000076  0.000027
#
#                                lag4      lag5
# time
# 2019-01-01 22:30:00+00:00 -0.000026 -0.000201
# 2019-01-01 22:35:00+00:00  0.000000 -0.000026
# 2019-01-01 22:40:00+00:00  0.000183  0.000000
# 2019-01-01 22:45:00+00:00 -0.000048  0.000183
# 2019-01-01 22:50:00+00:00 -0.000017 -0.000048
# ...                             ...       ...
# 2019-12-30 23:35:00+00:00 -0.000004  0.000089
# 2019-12-30 23:40:00+00:00  0.000022 -0.000004
# 2019-12-30 23:45:00+00:00 -0.000018  0.000022
# 2019-12-30 23:50:00+00:00 -0.000112 -0.000018
# 2019-12-30 23:55:00+00:00 -0.000004 -0.000112
#
# [73714 rows x 7 columns]

# %%
cols
# Out:
# ['lag1', 'lag2', 'lag3', 'lag4', 'lag5']

# %%
lm = LinearRegression(fit_intercept = True)

# %%
lm.fit(data[cols], data.returns)
# Out:
# LinearRegression()

# %%
lm.coef_
# Out:
# array([-0.03358358, -0.00243139,  0.00365238, -0.00366896, -0.00360391])

# %%
lm.intercept_
# Out:
# -3.2782924419950654e-07

# %%
data["pred"] = lm.predict(data[cols])

# %%
data.pred = np.sign(data.pred)

# %%
data
# Out:
#                               price   returns      lag1      lag2      lag3  \
# time
# 2019-01-01 22:30:00+00:00  1.146455 -0.000017 -0.000048  0.000183  0.000000
# 2019-01-01 22:35:00+00:00  1.146455  0.000000 -0.000017 -0.000048  0.000183
# 2019-01-01 22:40:00+00:00  1.146370 -0.000074  0.000000 -0.000017 -0.000048
# 2019-01-01 22:45:00+00:00  1.146315 -0.000048 -0.000074  0.000000 -0.000017
# 2019-01-01 22:50:00+00:00  1.146475  0.000140 -0.000048 -0.000074  0.000000
# ...                             ...       ...       ...       ...       ...
# 2019-12-30 23:35:00+00:00  1.120180 -0.000004 -0.000112 -0.000018  0.000022
# 2019-12-30 23:40:00+00:00  1.120210  0.000027 -0.000004 -0.000112 -0.000018
# 2019-12-30 23:45:00+00:00  1.120295  0.000076  0.000027 -0.000004 -0.000112
# 2019-12-30 23:50:00+00:00  1.120275 -0.000018  0.000076  0.000027 -0.000004
# 2019-12-30 23:55:00+00:00  1.120130 -0.000129 -0.000018  0.000076  0.000027
#
#                                lag4      lag5  pred
# time
# 2019-01-01 22:30:00+00:00 -0.000026 -0.000201   1.0
# 2019-01-01 22:35:00+00:00  0.000000 -0.000026   1.0
# 2019-01-01 22:40:00+00:00  0.000183  0.000000  -1.0
# 2019-01-01 22:45:00+00:00 -0.000048  0.000183   1.0
# 2019-01-01 22:50:00+00:00 -0.000017 -0.000048   1.0
# ...                             ...       ...   ...
# 2019-12-30 23:35:00+00:00 -0.000004  0.000089   1.0
# 2019-12-30 23:40:00+00:00  0.000022 -0.000004  -1.0
# 2019-12-30 23:45:00+00:00 -0.000018  0.000022  -1.0
# 2019-12-30 23:50:00+00:00 -0.000112 -0.000018  -1.0
# 2019-12-30 23:55:00+00:00 -0.000004 -0.000112   1.0
#
# [73714 rows x 8 columns]

# %%
data.pred.value_counts()
# Out:
# pred
# -1.0    39610
#  1.0    34104
# Name: count, dtype: int64

# %%
hits = np.sign(data.returns * data.pred).value_counts()

# %%
hits
# Out:
#  1.0    37493
# -1.0    34263
#  0.0     1958
# Name: count, dtype: int64

# %%
hit_ratio = hits[1.0] / sum(hits)
hit_ratio
# Out:
# 0.5086279404183737

# %% [markdown]
# ## In-Sample Backtesting and the Look-ahead-bias

# %%
data
# Out:
#                               price   returns      lag1      lag2      lag3  \
# time
# 2019-01-01 22:30:00+00:00  1.146455 -0.000017 -0.000048  0.000183  0.000000
# 2019-01-01 22:35:00+00:00  1.146455  0.000000 -0.000017 -0.000048  0.000183
# 2019-01-01 22:40:00+00:00  1.146370 -0.000074  0.000000 -0.000017 -0.000048
# 2019-01-01 22:45:00+00:00  1.146315 -0.000048 -0.000074  0.000000 -0.000017
# 2019-01-01 22:50:00+00:00  1.146475  0.000140 -0.000048 -0.000074  0.000000
# ...                             ...       ...       ...       ...       ...
# 2019-12-30 23:35:00+00:00  1.120180 -0.000004 -0.000112 -0.000018  0.000022
# 2019-12-30 23:40:00+00:00  1.120210  0.000027 -0.000004 -0.000112 -0.000018
# 2019-12-30 23:45:00+00:00  1.120295  0.000076  0.000027 -0.000004 -0.000112
# 2019-12-30 23:50:00+00:00  1.120275 -0.000018  0.000076  0.000027 -0.000004
# 2019-12-30 23:55:00+00:00  1.120130 -0.000129 -0.000018  0.000076  0.000027
#
#                                lag4      lag5  pred
# time
# 2019-01-01 22:30:00+00:00 -0.000026 -0.000201   1.0
# 2019-01-01 22:35:00+00:00  0.000000 -0.000026   1.0
# 2019-01-01 22:40:00+00:00  0.000183  0.000000  -1.0
# 2019-01-01 22:45:00+00:00 -0.000048  0.000183   1.0
# 2019-01-01 22:50:00+00:00 -0.000017 -0.000048   1.0
# ...                             ...       ...   ...
# 2019-12-30 23:35:00+00:00 -0.000004  0.000089   1.0
# 2019-12-30 23:40:00+00:00  0.000022 -0.000004  -1.0
# 2019-12-30 23:45:00+00:00 -0.000018  0.000022  -1.0
# 2019-12-30 23:50:00+00:00 -0.000112 -0.000018  -1.0
# 2019-12-30 23:55:00+00:00 -0.000004 -0.000112   1.0
#
# [73714 rows x 8 columns]

# %%
data["strategy"] = data.pred * data.returns

# %%
data["creturns"] = data["returns"].cumsum().apply(np.exp)
data["cstrategy"] = data["strategy"].cumsum().apply(np.exp)

# %%
data[["creturns", "cstrategy"]].plot(figsize = (12 , 8))
plt.show()

# %%
data.pred.diff().fillna(0).abs()
# Out:
# time
# 2020-01-01 22:40:00+00:00    0.0
# 2020-01-01 22:45:00+00:00    2.0
# 2020-01-01 22:50:00+00:00    0.0
# 2020-01-01 22:55:00+00:00    0.0
# 2020-01-01 23:00:00+00:00    2.0
#                             ...
# 2020-08-30 23:35:00+00:00    2.0
# 2020-08-30 23:40:00+00:00    0.0
# 2020-08-30 23:45:00+00:00    2.0
# 2020-08-30 23:50:00+00:00    0.0
# 2020-08-30 23:55:00+00:00    0.0
# Name: pred, Length: 49361, dtype: float64

# %%
data["trades"] = data.pred.diff().fillna(0).abs()

# %%
data.trades.value_counts()
# Out:
# trades
# 0.0    37100
# 2.0    36614
# Name: count, dtype: int64

# %%
data
# Out:
#                               price   returns      lag1      lag2      lag3  \
# time
# 2019-01-01 22:30:00+00:00  1.146455 -0.000017 -0.000048  0.000183  0.000000
# 2019-01-01 22:35:00+00:00  1.146455  0.000000 -0.000017 -0.000048  0.000183
# 2019-01-01 22:40:00+00:00  1.146370 -0.000074  0.000000 -0.000017 -0.000048
# 2019-01-01 22:45:00+00:00  1.146315 -0.000048 -0.000074  0.000000 -0.000017
# 2019-01-01 22:50:00+00:00  1.146475  0.000140 -0.000048 -0.000074  0.000000
# ...                             ...       ...       ...       ...       ...
# 2019-12-30 23:35:00+00:00  1.120180 -0.000004 -0.000112 -0.000018  0.000022
# 2019-12-30 23:40:00+00:00  1.120210  0.000027 -0.000004 -0.000112 -0.000018
# 2019-12-30 23:45:00+00:00  1.120295  0.000076  0.000027 -0.000004 -0.000112
# 2019-12-30 23:50:00+00:00  1.120275 -0.000018  0.000076  0.000027 -0.000004
# 2019-12-30 23:55:00+00:00  1.120130 -0.000129 -0.000018  0.000076  0.000027
#
#                                lag4      lag5  pred  strategy  creturns  \
# time
# 2019-01-01 22:30:00+00:00 -0.000026 -0.000201   1.0 -0.000017  0.999983
# 2019-01-01 22:35:00+00:00  0.000000 -0.000026   1.0  0.000000  0.999983
# 2019-01-01 22:40:00+00:00  0.000183  0.000000  -1.0  0.000074  0.999908
# 2019-01-01 22:45:00+00:00 -0.000048  0.000183   1.0 -0.000048  0.999860
# 2019-01-01 22:50:00+00:00 -0.000017 -0.000048   1.0  0.000140  1.000000
# ...                             ...       ...   ...       ...       ...
# 2019-12-30 23:35:00+00:00 -0.000004  0.000089   1.0 -0.000004  0.977064
# 2019-12-30 23:40:00+00:00  0.000022 -0.000004  -1.0 -0.000027  0.977091
# 2019-12-30 23:45:00+00:00 -0.000018  0.000022  -1.0 -0.000076  0.977165
# 2019-12-30 23:50:00+00:00 -0.000112 -0.000018  -1.0  0.000018  0.977147
# 2019-12-30 23:55:00+00:00 -0.000004 -0.000112   1.0 -0.000129  0.977021
#
#                            cstrategy  trades
# time
# 2019-01-01 22:30:00+00:00   0.999983     0.0
# 2019-01-01 22:35:00+00:00   0.999983     0.0
# 2019-01-01 22:40:00+00:00   1.000057     2.0
# 2019-01-01 22:45:00+00:00   1.000009     2.0
# 2019-01-01 22:50:00+00:00   1.000148     0.0
# ...                              ...     ...
# 2019-12-30 23:35:00+00:00   1.519495     2.0
# 2019-12-30 23:40:00+00:00   1.519454     2.0
# 2019-12-30 23:45:00+00:00   1.519339     0.0
# 2019-12-30 23:50:00+00:00   1.519366     0.0
# 2019-12-30 23:55:00+00:00   1.519170     2.0
#
# [73714 rows x 12 columns]

# %% [markdown]
# ## Out-Sample Forward Testing

# %%
data = pd.read_csv("test_set.csv", parse_dates = ["time"], index_col = "time")

# %%
data
# Out:
#                               price
# time
# 2020-01-01 22:00:00+00:00  1.121325
# 2020-01-01 22:05:00+00:00  1.121250
# 2020-01-01 22:10:00+00:00  1.121250
# 2020-01-01 22:15:00+00:00  1.121460
# 2020-01-01 22:20:00+00:00  1.121540
# ...                             ...
# 2020-08-30 23:35:00+00:00  1.190895
# 2020-08-30 23:40:00+00:00  1.191240
# 2020-08-30 23:45:00+00:00  1.191515
# 2020-08-30 23:50:00+00:00  1.191685
# 2020-08-30 23:55:00+00:00  1.191715
#
# [49367 rows x 1 columns]

# %%
data["returns"] = np.log(data.div(data.shift(1)))

# %%
data
# Out:
#                               price   returns
# time
# 2020-01-01 22:00:00+00:00  1.121325       NaN
# 2020-01-01 22:05:00+00:00  1.121250 -0.000067
# 2020-01-01 22:10:00+00:00  1.121250  0.000000
# 2020-01-01 22:15:00+00:00  1.121460  0.000187
# 2020-01-01 22:20:00+00:00  1.121540  0.000071
# ...                             ...       ...
# 2020-08-30 23:35:00+00:00  1.190895 -0.000080
# 2020-08-30 23:40:00+00:00  1.191240  0.000290
# 2020-08-30 23:45:00+00:00  1.191515  0.000231
# 2020-08-30 23:50:00+00:00  1.191685  0.000143
# 2020-08-30 23:55:00+00:00  1.191715  0.000025
#
# [49367 rows x 2 columns]

# %%
lags = 5

# %%
cols = []
for lag in range(1, lags + 1):
    col = "lag{}".format(lag)
    data[col] = data.returns.shift(lag)
    cols.append(col)
data.dropna(inplace = True)

# %%
data
# Out:
#                               price   returns      lag1      lag2      lag3  \
# time
# 2020-01-01 22:40:00+00:00  1.121520  0.000004 -0.000022  0.000071  0.000187
# 2020-01-01 22:45:00+00:00  1.121555  0.000031  0.000004 -0.000022  0.000071
# 2020-01-01 22:50:00+00:00  1.121550 -0.000004  0.000031  0.000004 -0.000022
# 2020-01-01 22:55:00+00:00  1.121515 -0.000031 -0.000004  0.000031  0.000004
# 2020-01-01 23:00:00+00:00  1.121915  0.000357 -0.000031 -0.000004  0.000031
# ...                             ...       ...       ...       ...       ...
# 2020-08-30 23:35:00+00:00  1.190895 -0.000080 -0.000092  0.000298  0.000046
# 2020-08-30 23:40:00+00:00  1.191240  0.000290 -0.000080 -0.000092  0.000298
# 2020-08-30 23:45:00+00:00  1.191515  0.000231  0.000290 -0.000080 -0.000092
# 2020-08-30 23:50:00+00:00  1.191685  0.000143  0.000231  0.000290 -0.000080
# 2020-08-30 23:55:00+00:00  1.191715  0.000025  0.000143  0.000231  0.000290
#
#                                lag4      lag5
# time
# 2020-01-01 22:40:00+00:00  0.000000 -0.000067
# 2020-01-01 22:45:00+00:00  0.000187  0.000000
# 2020-01-01 22:50:00+00:00  0.000071  0.000187
# 2020-01-01 22:55:00+00:00 -0.000022  0.000071
# 2020-01-01 23:00:00+00:00  0.000004 -0.000022
# ...                             ...       ...
# 2020-08-30 23:35:00+00:00  0.000000 -0.000151
# 2020-08-30 23:40:00+00:00  0.000046  0.000000
# 2020-08-30 23:45:00+00:00  0.000298  0.000046
# 2020-08-30 23:50:00+00:00 -0.000092  0.000298
# 2020-08-30 23:55:00+00:00 -0.000080 -0.000092
#
# [49361 rows x 7 columns]

# %%
data["pred"] = lm.predict(data[cols])

# %%
data
# Out:
#                               price   returns      lag1      lag2      lag3  \
# time
# 2020-01-01 22:40:00+00:00  1.121520  0.000004 -0.000022  0.000071  0.000187
# 2020-01-01 22:45:00+00:00  1.121555  0.000031  0.000004 -0.000022  0.000071
# 2020-01-01 22:50:00+00:00  1.121550 -0.000004  0.000031  0.000004 -0.000022
# 2020-01-01 22:55:00+00:00  1.121515 -0.000031 -0.000004  0.000031  0.000004
# 2020-01-01 23:00:00+00:00  1.121915  0.000357 -0.000031 -0.000004  0.000031
# ...                             ...       ...       ...       ...       ...
# 2020-08-30 23:35:00+00:00  1.190895 -0.000080 -0.000092  0.000298  0.000046
# 2020-08-30 23:40:00+00:00  1.191240  0.000290 -0.000080 -0.000092  0.000298
# 2020-08-30 23:45:00+00:00  1.191515  0.000231  0.000290 -0.000080 -0.000092
# 2020-08-30 23:50:00+00:00  1.191685  0.000143  0.000231  0.000290 -0.000080
# 2020-08-30 23:55:00+00:00  1.191715  0.000025  0.000143  0.000231  0.000290
#
#                                lag4      lag5          pred
# time
# 2020-01-01 22:40:00+00:00  0.000000 -0.000067  1.172394e-06
# 2020-01-01 22:45:00+00:00  0.000187  0.000000 -8.499182e-07
# 2020-01-01 22:50:00+00:00  0.000071  0.000187 -2.404767e-06
# 2020-01-01 22:55:00+00:00 -0.000022  0.000071 -4.129965e-07
# 2020-01-01 23:00:00+00:00  0.000004 -0.000022  9.090211e-07
# ...                             ...       ...           ...
# 2020-08-30 23:35:00+00:00  0.000000 -0.000151  2.762520e-06
# 2020-08-30 23:40:00+00:00  0.000046  0.000000  3.494904e-06
# 2020-08-30 23:45:00+00:00  0.000298  0.000046 -1.145903e-05
# 2020-08-30 23:50:00+00:00 -0.000092  0.000298 -9.810814e-06
# 2020-08-30 23:55:00+00:00 -0.000080 -0.000092 -3.996825e-06
#
# [49361 rows x 8 columns]

# %%
data.pred = np.sign(data.pred)

# %%
data.pred.value_counts()
# Out:
# pred
# -1.0    26143
#  1.0    23218
# Name: count, dtype: int64

# %%
hits = np.sign(data.returns * data.pred).value_counts()

# %%
hits
# Out:
#  1.0    24995
# -1.0    23754
#  0.0      612
# Name: count, dtype: int64

# %%
hit_ratio = hits[1.0] / sum(hits)
hit_ratio
# Out:
# 0.5063714268349506

# %%
data["strategy"] = data.pred * data.returns

# %%
data["creturns"] = data["returns"].cumsum().apply(np.exp)
data["cstrategy"] = data["strategy"].cumsum().apply(np.exp)

# %%
data[["creturns", "cstrategy"]].plot(figsize = (12 , 8))
plt.show()

# %%
data["trades"] = data.pred.diff().fillna(0).abs()

# %%
data.trades.value_counts()
# Out:
# trades
# 0.0    25190
# 2.0    24171
# Name: count, dtype: int64
