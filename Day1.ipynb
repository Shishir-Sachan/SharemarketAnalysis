# %%
import pandas as pd
import yfinance as yf

# %%
start = '2014-01-01'
end = '2024-02-07'

# %%
symbol = "VEDL.NS"

# %%
yf.download(symbol, start, end)
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2014-01-01  202.550003  203.899994  201.500000  202.000000   74.414970
# 2014-01-02  201.500000  207.250000  196.850006  199.850006   73.622925
# 2014-01-03  198.850006  200.000000  196.100006  199.149994   73.365036
# 2014-01-06  198.000000  199.800003  196.100006  198.949997   73.291382
# 2014-01-07  198.300003  201.300003  193.649994  194.500000   71.652046
# ...                ...         ...         ...         ...         ...
# 2024-01-31  266.799988  276.899994  265.750000  273.850006  273.850006
# 2024-02-01  275.450012  276.500000  265.049988  268.500000  268.500000
# 2024-02-02  270.200012  276.799988  268.750000  272.549988  272.549988
# 2024-02-05  272.850006  279.850006  271.549988  273.600006  273.600006
# 2024-02-06  273.700012  284.500000  269.850006  283.000000  283.000000
#
#               Volume
# Date
# ...

# %%
df = yf.download(symbol, start, end)
df
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2014-01-01  202.550003  203.899994  201.500000  202.000000   74.414970
# 2014-01-02  201.500000  207.250000  196.850006  199.850006   73.622925
# 2014-01-03  198.850006  200.000000  196.100006  199.149994   73.365036
# 2014-01-06  198.000000  199.800003  196.100006  198.949997   73.291382
# 2014-01-07  198.300003  201.300003  193.649994  194.500000   71.652046
# ...                ...         ...         ...         ...         ...
# 2024-01-31  266.799988  276.899994  265.750000  273.850006  273.850006
# 2024-02-01  275.450012  276.500000  265.049988  268.500000  268.500000
# 2024-02-02  270.200012  276.799988  268.750000  272.549988  272.549988
# 2024-02-05  272.850006  279.850006  271.549988  273.600006  273.600006
# 2024-02-06  273.700012  284.500000  269.850006  283.000000  283.000000
#
#               Volume
# Date
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2491 entries, 2014-01-01 to 2024-02-06
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       2491 non-null   float64
#  1   High       2491 non-null   float64
#  2   Low        2491 non-null   float64
#  3   Close      2491 non-null   float64
#  4   Adj Close  2491 non-null   float64
#  5   Volume     2491 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 136.2 KB

# %%
symbol =["TCS.NS", "VEDL.NS", "WIPRO.NS", "INFY.NS"]

# %%
df = yf.download(symbol, start, end)
df
# Out:
# [*********************100%%**********************]  4 of 4 completed
# Price         Adj Close                                             Close  \
# Ticker          INFY.NS       TCS.NS     VEDL.NS    WIPRO.NS      INFY.NS
# Date
# 2014-01-01   336.827667   869.126038   74.414970  191.799255   433.500000
# 2014-01-02   338.046631   874.655945   73.622925  191.886002   435.068756
# 2014-01-03   346.263275   896.935852   73.365036  193.152649   445.643738
# 2014-01-06   341.674286   903.959045   73.291382  193.638443   439.737488
# 2014-01-07   335.773926   890.457703   71.652046  190.931717   432.143738
# ...                 ...          ...         ...         ...          ...
# 2024-01-31  1660.900024  3815.949951  273.850006  478.149994  1660.900024
# 2024-02-01  1657.050049  3854.149902  268.500000  471.350006  1657.050049
# 2024-02-02  1693.349976  3966.300049  272.549988  483.149994  1693.349976
# 2024-02-05  1687.199951  3973.300049  273.600006  482.350006  1687.199951
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2491 entries, 2014-01-01 to 2024-02-06
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   (Adj Close, INFY.NS)   2491 non-null   float64
#  1   (Adj Close, TCS.NS)    2491 non-null   float64
#  2   (Adj Close, VEDL.NS)   2491 non-null   float64
#  3   (Adj Close, WIPRO.NS)  2491 non-null   float64
#  4   (Close, INFY.NS)       2491 non-null   float64
#  5   (Close, TCS.NS)        2491 non-null   float64
#  6   (Close, VEDL.NS)       2491 non-null   float64
#  7   (Close, WIPRO.NS)      2491 non-null   float64
#  8   (High, INFY.NS)        2491 non-null   float64
#  9   (High, TCS.NS)         2491 non-null   float64
#  10  (High, VEDL.NS)        2491 non-null   float64
#  11  (High, WIPRO.NS)       2491 non-null   float64
#  12  (Low, INFY.NS)         2491 non-null   float64
#  13  (Low, TCS.NS)          2491 non-null   float64
# ...

# %%
df.to_csv("multi_assets.csv")

# %%
# Initial Inspection and Visualization

# %%
import pandas as pd
import matplotlib.pyplot as plt
pd.options.display.float_format = '{:.4f}'.format
# plt.style.use("seaborn")
plt.style.use("seaborn-v0_8")

# %%
pd.read_csv("multi_assets.csv", header = [0,1], index_col = 0, parse_dates=[0])
# Out:
# Price      Adj Close                                 Close                     \
# Ticker       INFY.NS    TCS.NS  VEDL.NS WIPRO.NS   INFY.NS    TCS.NS  VEDL.NS
# Date
# 2014-01-01  336.8277  869.1260  74.4150 191.7993  433.5000 1076.6500 202.0000
# 2014-01-02  338.0466  874.6559  73.6229 191.8860  435.0688 1083.5000 199.8500
# 2014-01-03  346.2633  896.9359  73.3650 193.1526  445.6437 1111.1000 199.1500
# 2014-01-06  341.6743  903.9590  73.2914 193.6384  439.7375 1119.8000 198.9500
# 2014-01-07  335.7739  890.4577  71.6520 190.9317  432.1437 1103.0750 194.5000
# ...              ...       ...      ...      ...       ...       ...      ...
# 2024-01-31 1660.9000 3815.9500 273.8500 478.1500 1660.9000 3815.9500 273.8500
# 2024-02-01 1657.0500 3854.1499 268.5000 471.3500 1657.0500 3854.1499 268.5000
# 2024-02-02 1693.3500 3966.3000 272.5500 483.1500 1693.3500 3966.3000 272.5500
# 2024-02-05 1687.2000 3973.3000 273.6000 482.3500 1687.2000 3973.3000 273.6000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2491 entries, 2014-01-01 to 2024-02-06
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   (Adj Close, INFY.NS)   2491 non-null   float64
#  1   (Adj Close, TCS.NS)    2491 non-null   float64
#  2   (Adj Close, VEDL.NS)   2491 non-null   float64
#  3   (Adj Close, WIPRO.NS)  2491 non-null   float64
#  4   (Close, INFY.NS)       2491 non-null   float64
#  5   (Close, TCS.NS)        2491 non-null   float64
#  6   (Close, VEDL.NS)       2491 non-null   float64
#  7   (Close, WIPRO.NS)      2491 non-null   float64
#  8   (High, INFY.NS)        2491 non-null   float64
#  9   (High, TCS.NS)         2491 non-null   float64
#  10  (High, VEDL.NS)        2491 non-null   float64
#  11  (High, WIPRO.NS)       2491 non-null   float64
#  12  (Low, INFY.NS)         2491 non-null   float64
#  13  (Low, TCS.NS)          2491 non-null   float64
# ...

# %%
df.Close # outer index level
# Out:
# Ticker       INFY.NS    TCS.NS  VEDL.NS  WIPRO.NS
# Date
# 2014-01-01  433.5000 1076.6500 202.0000  207.2626
# 2014-01-02  435.0688 1083.5000 199.8500  207.3563
# 2014-01-03  445.6437 1111.1000 199.1500  208.7251
# 2014-01-06  439.7375 1119.8000 198.9500  209.2500
# 2014-01-07  432.1437 1103.0750 194.5000  206.3251
# ...              ...       ...      ...       ...
# 2024-01-31 1660.9000 3815.9500 273.8500  478.1500
# 2024-02-01 1657.0500 3854.1499 268.5000  471.3500
# 2024-02-02 1693.3500 3966.3000 272.5500  483.1500
# 2024-02-05 1687.2000 3973.3000 273.6000  482.3500
# 2024-02-06 1729.4500 4136.0000 283.0000  499.6500
#
# [2491 rows x 4 columns]

# %%
df.Close['VEDL.NS'] # one cloumn (1)
# Out:
# Date
# 2014-01-01   202.0000
# 2014-01-02   199.8500
# 2014-01-03   199.1500
# 2014-01-06   198.9500
# 2014-01-07   194.5000
#                ...
# 2024-01-31   273.8500
# 2024-02-01   268.5000
# 2024-02-02   272.5500
# 2024-02-05   273.6000
# 2024-02-06   283.0000
# Name: VEDL.NS, Length: 2491, dtype: float64

# %%
df.loc[:, ("Close", "VEDL.NS")]
# Out:
# Date
# 2014-01-01   202.0000
# 2014-01-02   199.8500
# 2014-01-03   199.1500
# 2014-01-06   198.9500
# 2014-01-07   194.5000
#                ...
# 2024-01-31   273.8500
# 2024-02-01   268.5000
# 2024-02-02   272.5500
# 2024-02-05   273.6000
# 2024-02-06   283.0000
# Name: (Close, VEDL.NS), Length: 2491, dtype: float64

# %%
df.loc['2015-01-07'] # oned day /row
# Out:
# Price      Ticker
# Adj Close  INFY.NS        389.6402
#            TCS.NS        1004.3777
#            VEDL.NS         77.9630
#            WIPRO.NS       190.5058
# Close      INFY.NS        490.8875
#            TCS.NS        1208.8500
#            VEDL.NS        209.0000
#            WIPRO.NS       202.9126
# High       INFY.NS        493.6875
#            TCS.NS        1239.5750
#            VEDL.NS        211.8500
#            WIPRO.NS       204.3750
# Low        INFY.NS        487.5000
#            TCS.NS        1203.7250
#            VEDL.NS        204.1500
#            WIPRO.NS       201.8813
# Open       INFY.NS        491.2500
#            TCS.NS        1235.0000
#            VEDL.NS        209.0000
#            WIPRO.NS       203.7000
# Volume     INFY.NS    7249916.0000
#            TCS.NS     2636332.0000
#            VEDL.NS    3410940.0000
#            WIPRO.NS   4152790.0000
# Name: 2015-01-07 00:00:00, dtype: float64

# %%
df.loc["2015"] #one year
# Out:
# Price      Adj Close                               Close                     \
# Ticker       INFY.NS    TCS.NS VEDL.NS WIPRO.NS  INFY.NS    TCS.NS  VEDL.NS
# Date
# 2015-01-01  391.7932 1057.4904 81.7866 194.4842 493.6000 1272.7750 219.2500
# 2015-01-02  399.4926 1071.5723 82.9243 196.2094 503.3000 1289.7250 222.3000
# 2015-01-05  396.0596 1055.2883 81.9917 196.5614 498.9750 1270.1250 219.8000
# 2015-01-06  387.7848 1016.3831 77.9817 191.9669 488.5500 1223.3000 209.0500
# 2015-01-07  389.6402 1004.3777 77.9630 190.5058 490.8875 1208.8500 209.0000
# ...              ...       ...     ...      ...      ...       ...      ...
# 2015-12-24  445.7717 1031.6183 35.9542 200.3218 548.1750 1217.1250  91.9500
# 2015-12-28  449.1871 1043.6746 35.9346 201.8497 552.3750 1231.3500  91.9000
# 2015-12-29  449.1667 1040.7512 35.9542 202.7845 552.3500 1227.9000  91.9500
# 2015-12-30  441.6854 1024.8589 35.9542 200.6454 543.1500 1209.1500  91.9500
# ...

# %%
df.loc["2020-06":,("Close", "VEDL.NS")] #one month for one column
# Out:
# Date
# 2020-06-01    93.6500
# 2020-06-02    96.9000
# 2020-06-03    96.7000
# 2020-06-04   104.4000
# 2020-06-05   105.3000
#                ...
# 2024-01-31   273.8500
# 2024-02-01   268.5000
# 2024-02-02   272.5500
# 2024-02-05   273.6000
# 2024-02-06   283.0000
# Name: (Close, VEDL.NS), Length: 918, dtype: float64

# %%
df = df.swaplevel(axis = "columns").sort_index(axis = 'columns') # swap outer and inner index
df
# Out:
# Ticker       INFY.NS                                                    \
# Price      Adj Close     Close      High       Low      Open    Volume
# Date
# 2014-01-01  336.8277  433.5000  437.3750  432.7563  436.5000   1478688
# 2014-01-02  338.0466  435.0688  438.5000  432.9062  432.9062   4404744
# 2014-01-03  346.2633  445.6437  446.8750  431.7812  434.3750  10046344
# 2014-01-06  341.6743  439.7375  447.5625  433.5750  446.8875  11098328
# 2014-01-07  335.7739  432.1437  440.7375  430.8375  439.8813   7713688
# ...              ...       ...       ...       ...       ...       ...
# 2024-01-31 1660.9000 1660.9000 1667.2500 1638.1000 1648.2500   6763779
# 2024-02-01 1657.0500 1657.0500 1677.0000 1650.3500 1659.5500   5760011
# 2024-02-02 1693.3500 1693.3500 1718.5000 1665.0000 1666.0500   7858483
# 2024-02-05 1687.2000 1687.2000 1700.7500 1681.8500 1694.7500   3634135
# 2024-02-06 1729.4500 1729.4500 1733.0000 1673.9500 1686.7500   7694265
#
# ...

# %%
df["VEDL.NS"]
# Out:
# Price       Adj Close    Close     High      Low     Open    Volume
# Date
# 2014-01-01    74.4150 202.0000 203.9000 201.5000 202.5500   1367554
# 2014-01-02    73.6229 199.8500 207.2500 196.8500 201.5000   5835175
# 2014-01-03    73.3650 199.1500 200.0000 196.1000 198.8500   3236296
# 2014-01-06    73.2914 198.9500 199.8000 196.1000 198.0000   5207405
# 2014-01-07    71.6520 194.5000 201.3000 193.6500 198.3000   2930763
# ...               ...      ...      ...      ...      ...       ...
# 2024-01-31   273.8500 273.8500 276.9000 265.7500 266.8000   9537630
# 2024-02-01   268.5000 268.5000 276.5000 265.0500 275.4500   7974578
# 2024-02-02   272.5500 272.5500 276.8000 268.7500 270.2000   9665486
# 2024-02-05   273.6000 273.6000 279.8500 271.5500 272.8500  10619393
# 2024-02-06   283.0000 283.0000 284.5000 269.8500 273.7000  11559491
#
# [2491 rows x 6 columns]

# %%
df["TCS.NS"]
# Out:
# Price       Adj Close     Close      High       Low      Open   Volume
# Date
# 2014-01-01   869.1260 1076.6500 1092.2500 1075.5500 1090.0500   529952
# 2014-01-02   874.6559 1083.5000 1094.5000 1078.0750 1083.0000  1726948
# 2014-01-03   896.9359 1111.1000 1114.5500 1073.6250 1082.3500  2618174
# 2014-01-06   903.9590 1119.8000 1122.0000 1098.5000 1114.5000  2311810
# 2014-01-07   890.4577 1103.0750 1128.2250 1099.5000 1120.0000  2897486
# ...               ...       ...       ...       ...       ...      ...
# 2024-01-31  3815.9500 3815.9500 3834.0000 3796.4500 3811.2000  2459358
# 2024-02-01  3854.1499 3854.1499 3904.8999 3805.0500 3820.0000  2363107
# 2024-02-02  3966.3000 3966.3000 3984.3999 3872.0000 3875.0500  2826510
# 2024-02-05  3973.3000 3973.3000 4022.0000 3962.1001 3983.0000  1691523
# 2024-02-06  4136.0000 4136.0000 4149.8999 3990.0000 3997.0000  4474396
#
# [2491 rows x 6 columns]

# %%
df = df.swaplevel(axis = "columns").sort_index(axis = 'columns') # swap outer and inner index
df
# Out:
# Price      Adj Close                                 Close                     \
# Ticker       INFY.NS    TCS.NS  VEDL.NS WIPRO.NS   INFY.NS    TCS.NS  VEDL.NS
# Date
# 2014-01-01  336.8277  869.1260  74.4150 191.7993  433.5000 1076.6500 202.0000
# 2014-01-02  338.0466  874.6559  73.6229 191.8860  435.0688 1083.5000 199.8500
# 2014-01-03  346.2633  896.9359  73.3650 193.1526  445.6437 1111.1000 199.1500
# 2014-01-06  341.6743  903.9590  73.2914 193.6384  439.7375 1119.8000 198.9500
# 2014-01-07  335.7739  890.4577  71.6520 190.9317  432.1437 1103.0750 194.5000
# ...              ...       ...      ...      ...       ...       ...      ...
# 2024-01-31 1660.9000 3815.9500 273.8500 478.1500 1660.9000 3815.9500 273.8500
# 2024-02-01 1657.0500 3854.1499 268.5000 471.3500 1657.0500 3854.1499 268.5000
# 2024-02-02 1693.3500 3966.3000 272.5500 483.1500 1693.3500 3966.3000 272.5500
# 2024-02-05 1687.2000 3973.3000 273.6000 482.3500 1687.2000 3973.3000 273.6000
# ...

# %%
close = df.Close.copy() # select daily close prices only
close
# Out:
# Ticker       INFY.NS    TCS.NS  VEDL.NS  WIPRO.NS
# Date
# 2014-01-01  433.5000 1076.6500 202.0000  207.2626
# 2014-01-02  435.0688 1083.5000 199.8500  207.3563
# 2014-01-03  445.6437 1111.1000 199.1500  208.7251
# 2014-01-06  439.7375 1119.8000 198.9500  209.2500
# 2014-01-07  432.1437 1103.0750 194.5000  206.3251
# ...              ...       ...      ...       ...
# 2024-01-31 1660.9000 3815.9500 273.8500  478.1500
# 2024-02-01 1657.0500 3854.1499 268.5000  471.3500
# 2024-02-02 1693.3500 3966.3000 272.5500  483.1500
# 2024-02-05 1687.2000 3973.3000 273.6000  482.3500
# 2024-02-06 1729.4500 4136.0000 283.0000  499.6500
#
# [2491 rows x 4 columns]

# %%
close.describe()
# Out:
# Ticker   INFY.NS    TCS.NS   VEDL.NS  WIPRO.NS
# count  2491.0000 2491.0000 2491.0000 2491.0000
# mean    888.9494 2139.0774  219.4668  302.0883
# std     450.7157  931.6513   78.6791  131.7231
# min     365.5625 1018.3500   61.5500  162.3500
# 25%     520.0125 1260.3250  161.3250  208.0313
# 50%     687.6500 1981.4000  224.0500  239.4500
# 75%    1361.6000 3175.4500  280.2500  395.2500
# max    1939.5000 4136.0000  437.7500  721.5000

# %%
close["VEDL.NS"].dropna().plot(figsize =(15,8), fontsize =13)
plt.legend(fontsize = 13)
plt.show()

# %%
close.dropna().plot(figsize =(15, 8), fontsize = 13)
plt.legend(fontsize = 13)
plt.show()

# %% [markdown]
# ### Take Home : Absolute prices are absolutely meaningless/useless(in most cases)
#      prices that are on a different scale are hard to compare
#      A higher pricedoes not imply a higher value or a better performance

# %%
# Normalizing financial time series to a base value (100)
# All instruments start at the very same level (base value)

# %%
close
# Out:
# Ticker       INFY.NS    TCS.NS  VEDL.NS  WIPRO.NS
# Date
# 2014-01-01  433.5000 1076.6500 202.0000  207.2626
# 2014-01-02  435.0688 1083.5000 199.8500  207.3563
# 2014-01-03  445.6437 1111.1000 199.1500  208.7251
# 2014-01-06  439.7375 1119.8000 198.9500  209.2500
# 2014-01-07  432.1437 1103.0750 194.5000  206.3251
# ...              ...       ...      ...       ...
# 2024-01-31 1660.9000 3815.9500 273.8500  478.1500
# 2024-02-01 1657.0500 3854.1499 268.5000  471.3500
# 2024-02-02 1693.3500 3966.3000 272.5500  483.1500
# 2024-02-05 1687.2000 3973.3000 273.6000  482.3500
# 2024-02-06 1729.4500 4136.0000 283.0000  499.6500
#
# [2491 rows x 4 columns]

# %%
close.iloc[0,0] # first price INFY.NS
# Out:
# 433.5

# %%
close["INFY.NS"].div(close.iloc[0,0]).mul(100)
# Out:
# Date
# 2014-01-01   100.0000
# 2014-01-02   100.3619
# 2014-01-03   102.8013
# 2014-01-06   101.4389
# 2014-01-07    99.6871
#                ...
# 2024-01-31   383.1373
# 2024-02-01   382.2491
# 2024-02-02   390.6228
# 2024-02-05   389.2041
# 2024-02-06   398.9504
# Name: INFY.NS, Length: 2491, dtype: float64

# %%
close.iloc[0,0] # first price INFY.NS
# Out:
# 433.5

# %%
norm = close.div(close.iloc[0]).mul(100)
norm
# Out:
# Ticker      INFY.NS   TCS.NS  VEDL.NS  WIPRO.NS
# Date
# 2014-01-01 100.0000 100.0000 100.0000  100.0000
# 2014-01-02 100.3619 100.6362  98.9356  100.0452
# 2014-01-03 102.8013 103.1997  98.5891  100.7056
# 2014-01-06 101.4389 104.0078  98.4901  100.9589
# 2014-01-07  99.6871 102.4544  96.2871   99.5477
# ...             ...      ...      ...       ...
# 2024-01-31 383.1373 354.4281 135.5693  230.6977
# 2024-02-01 382.2491 357.9761 132.9208  227.4169
# 2024-02-02 390.6228 368.3927 134.9257  233.1101
# 2024-02-05 389.2041 369.0429 135.4455  232.7241
# 2024-02-06 398.9504 384.1545 140.0990  241.0710
#
# [2491 rows x 4 columns]

# %%
norm.dropna().plot(figsize = (15,8), fontsize =13, logy = False)
plt.legend(fontsize = 13)
plt.show()
