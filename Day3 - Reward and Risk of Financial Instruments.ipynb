# %% [markdown]
# ###  Measuring reward and risk of an investment

# %%
# General rule in finance/investing: Higher risk must reward higher returns.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
pd.options.display.float_format = '{:.4f}'.format
plt.style.use("seaborn-v0_8")

# %%
Ved = pd.read_csv("Ved.csv", index_col = "Date", parse_dates = ["Date"])

# %%
Ved
# Out:
#               Price  Returns
# Date
# 2014-01-01 202.0000      NaN
# 2014-01-02 199.8500  -0.0106
# 2014-01-03 199.1500  -0.0035
# 2014-01-06 198.9500  -0.0010
# 2014-01-07 194.5000  -0.0224
# ...             ...      ...
# 2024-01-31 273.8500   0.0285
# 2024-02-01 268.5000  -0.0195
# 2024-02-02 272.5500   0.0151
# 2024-02-05 273.6000   0.0039
# 2024-02-06 283.0000   0.0344
#
# [2491 rows x 2 columns]

# %%
Ved.Price.plot(figsize = (15,8), fontsize = 13)
plt.legend(fontsize =13)
plt.show()

# %% [markdown]
# Reward: Positive Returns
#
# Risk: Volatility of returns

# %%
Ved.describe()
# Out:
#           Price   Returns
# count 2491.0000 2490.0000
# mean   219.4668    0.0005
# std     78.6791    0.0281
# min     61.5500   -0.2043
# 25%    161.3250   -0.0135
# 50%    224.0500    0.0004
# 75%    280.2500    0.0157
# max    437.7500    0.1858

# %%
mu = Ved.Returns.mean() # arithmetic mean return ---> reward

# %%
mu
# Out:
# 0.0005325235329965898

# %%
sigma = Ved.Returns.std() # standard deviation of returns ---> Risk/Volatility

# %%
sigma
# Out:
# 0.028051690937527116

# %%
np.sqrt(Ved.Returns.var()) # standard deviation
# Out:
# 0.028051690937527116
